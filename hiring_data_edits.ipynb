# %%
import pandas as pd
import numpy as np
from faker import Faker
from datetime import datetime, timedelta
import random

# %%
np.random.seed(42)

# %%
df = pd.read_csv('hiring_data_unedited.csv')
df.head()
# Out:
#       ID FP  BU Region    Approved On hold       Sourcing start  \
# 0   2304  F         96  2014-06-25     NaN  2014-07-02 00:00:00
# 1  14263  F         10  2014-06-24     NaN  2014-06-30 00:00:00
# 2   5394  P          7  2014-07-30     NaN  2014-08-07 00:00:00
# 3  16251  F          8  2014-07-27     NaN  2014-08-02 00:00:00
# 4   1537  P         22  2014-08-21     NaN  2014-08-28 00:00:00
#
#        Interview start        Interview end              Offered  \
# 0  2014-07-18 00:00:00  2014-08-06 00:00:00  2014-08-14 00:00:00
# 1  2014-07-12 00:00:00  2014-08-07 00:00:00  2014-08-12 00:00:00
# 2  2014-08-19 00:00:00                  NaN                  NaN
# 3  2014-08-21 00:00:00                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#                 Filled           Status
# 0  2014-08-23 00:00:00           Filled
# 1  2014-08-21 00:00:00           Filled
# 2                  NaN  Interview start
# 3                  NaN  Interview start
# 4                  NaN   Sourcing start

# %%
df.sample(10)
# Out:
#          ID FP  BU Region    Approved              On hold  \
# 151   19040  F         24  2014-07-25                  NaN
# 807   16302  P         98  2014-08-21                  NaN
# 621   18011  P         20  2014-08-01                  NaN
# 3978  11384  F          7  2014-08-21                  NaN
# 3998   1417  P          7  2014-08-09                  NaN
# 1747  12495  P          3  2014-06-03                  NaN
# 555    9350  P          3  2014-06-28                  NaN
# 4545  18578  P         99  2014-08-29                  NaN
# 1536  11179  P         17  2014-08-17                  NaN
# 4111   4080  P         24  2014-03-17  2014-04-04 00:00:00
#
#            Sourcing start      Interview start        Interview end  \
# 151   2014-08-01 00:00:00  2014-08-17 00:00:00                  NaN
# 807   2014-08-28 00:00:00                  NaN                  NaN
# 621   2014-08-07 00:00:00  2014-08-17 00:00:00                  NaN
# 3978  2014-08-27 00:00:00                  NaN                  NaN
# 3998  2014-08-14 00:00:00  2014-08-29 00:00:00                  NaN
# 1747  2014-06-08 00:00:00  2014-06-22 00:00:00  2014-07-21 00:00:00
# 555   2014-07-04 00:00:00  2014-07-16 00:00:00  2014-08-05 00:00:00
# 4545                  NaN                  NaN                  NaN
# 1536  2014-08-24 00:00:00                  NaN                  NaN
# 4111                  NaN                  NaN                  NaN
#
#                   Offered               Filled           Status
# 151                   NaN                  NaN  Interview start
# 807                   NaN                  NaN   Sourcing start
# 621                   NaN                  NaN  Interview start
# 3978                  NaN                  NaN   Sourcing start
# 3998                  NaN                  NaN  Interview start
# 1747  2014-07-30 00:00:00  2014-08-05 00:00:00           Filled
# 555   2014-08-12 00:00:00  2014-08-20 00:00:00           Filled
# 4545                  NaN                  NaN         Approved
# 1536                  NaN                  NaN   Sourcing start
# 4111                  NaN                  NaN          On hold

# %%
df.size
# Out:
# 54417

# %%
df['Role Type'] = np.random.choice(
    ['Technical', 'Non-Technical'],  # choices
    size=len(df),                     # one for each row
    p=[0.46, 0.54]                    # probability split
)

# %%
# Create Recruiting_Channel column with NaN initially
df['Recruiting Channel'] = np.nan

# Mask for rows with Interview start
mask = df['Interview start'].notna()

# %%
# Assign weighted random recruiting channels only where Interview start is not NaN
df.loc[mask, 'Recruiting Channel'] = np.random.choice(
    ['Referral', 'Internal', 'LinkedIn', 'Direct'],
    size=mask.sum(),
    p=[0.25, 0.20, 0.45, 0.10]
)
# Out:
# /tmp/ipython-input-2840451435.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['Internal' 'Referral' 'Internal' ... 'Internal' 'LinkedIn' 'Referral']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[mask, 'Recruiting Channel'] = np.random.choice(

# %%
# Create Offer_Bonus column with NaN initially
df['Offer Bonus'] = np.nan

# Mask for rows where 'Offered' is not NaN
mask = df['Offered'].notna()

# Generate bonus for each applicable row
bonuses = []
for idx, row in df.loc[mask].iterrows():
    if row['Role Type'] == 'Technical':
        bonus_range = np.arange(12000, 30001, 500)  # higher range
    else:
        bonus_range = np.arange(5000, 25001, 500)   # lower range

    bonuses.append(np.random.choice(bonus_range))

# Assign back to dataframe
df.loc[mask, 'Offer Bonus'] = bonuses

# %%
# State/City list
locations = [
    ("New York", "NY"),
    ("San Francisco", "CA"),
    ("Austin", "TX"),
    ("Chicago", "IL"),
    ("Seattle", "WA"),
    ("Boston", "MA"),
    ("Atlanta", "GA"),
    ("Denver", "CO"),
    ("Miami", "FL"),
    ("Dallas", "TX")
]


# Randomly choose locations
chosen_locations = np.random.choice(len(locations), size=len(df))

# Assign city and state
df['City'] = [locations[i][0] for i in chosen_locations]
df['State'] = [locations[i][1] for i in chosen_locations]

# %%
df.sample(5)
# Out:
#          ID FP  BU Region    Approved On hold       Sourcing start  \
# 1937  19122  F          2  2014-05-28     NaN  2014-06-06 00:00:00
# 3149   9109  P         22  2014-08-26     NaN                  NaN
# 2857  14057  P          1  2014-08-07     NaN  2014-08-13 00:00:00
# 333   16124  P          3  2014-07-07     NaN  2014-07-15 00:00:00
# 3931   7665  F          8  2014-07-24     NaN  2014-07-31 00:00:00
#
#           Interview start        Interview end              Offered  \
# 1937  2014-06-23 00:00:00  2014-07-15 00:00:00  2014-07-24 00:00:00
# 3149                  NaN                  NaN                  NaN
# 2857                  NaN                  NaN                  NaN
# 333   2014-07-26 00:00:00  2014-08-20 00:00:00  2014-08-27 00:00:00
# 3931  2014-08-19 00:00:00                  NaN                  NaN
#
#                    Filled           Status      Role Type Recruiting Channel  \
# 1937  2014-08-02 00:00:00           Filled  Non-Technical           Referral
# 3149                  NaN         Approved      Technical                NaN
# 2857                  NaN   Sourcing start      Technical                NaN
# 333                   NaN          Offered      Technical           Internal
# 3931                  NaN  Interview start      Technical             Direct
#
#       Offer Bonus           City State
# 1937       9000.0  San Francisco    CA
# 3149          NaN       New York    NY
# 2857          NaN  San Francisco    CA
# 333       16000.0       New York    NY
# 3931          NaN         Denver    CO

# %%
df = df.drop(columns=["BU Region"]) # drop unused column

# %%
df.sample(5)
# Out:
#         ID FP    Approved On hold       Sourcing start      Interview start  \
# 392   1010  P  2014-06-16     NaN  2014-06-21 00:00:00  2014-07-07 00:00:00
# 495   1759  P  2014-07-03     NaN  2014-07-10 00:00:00  2014-07-24 00:00:00
# 2422  8977  F  2014-07-16     NaN  2014-07-21 00:00:00  2014-08-04 00:00:00
# 3800  8560  F  2014-08-25     NaN  2014-08-31 00:00:00                  NaN
# 3352  3985  F  2014-08-27     NaN                  NaN                  NaN
#
#             Interview end              Offered               Filled  \
# 392   2014-07-30 00:00:00  2014-08-04 00:00:00  2014-08-12 00:00:00
# 495   2014-08-15 00:00:00  2014-08-23 00:00:00  2014-08-28 00:00:00
# 2422                  NaN                  NaN                  NaN
# 3800                  NaN                  NaN                  NaN
# 3352                  NaN                  NaN                  NaN
#
#                Status      Role Type Recruiting Channel  Offer Bonus  \
# 392            Filled  Non-Technical             Direct      18000.0
# 495            Filled  Non-Technical           Internal       8500.0
# 2422  Interview start      Technical           LinkedIn          NaN
# 3800   Sourcing start  Non-Technical                NaN          NaN
# 3352         Approved  Non-Technical                NaN          NaN
#
#           City State
# 392    Atlanta    GA
# 495   New York    NY
# 2422  New York    NY
# 3800    Dallas    TX
# 3352   Atlanta    GA

# %%
df.loc[df['FP'].str.lower() == 'p', 'Offer Bonus'] = np.nan # add null value for part-time roles, assuming bonuses not given for part-time roles

# %%
df.sample(5)
# Out:
#          ID FP    Approved On hold       Sourcing start      Interview start  \
# 1388  17956  F  2014-08-24     NaN                  NaN                  NaN
# 1378   2542  F  2014-07-13     NaN  2014-07-19 00:00:00  2014-08-02 00:00:00
# 4416  16230  F  2014-06-23     NaN  2014-06-28 00:00:00  2014-07-09 00:00:00
# 3557   2680  P  2014-06-20     NaN  2014-06-27 00:00:00  2014-07-14 00:00:00
# 2105   6091  P  2014-07-31     NaN  2014-08-09 00:00:00  2014-08-26 00:00:00
#
#             Interview end              Offered               Filled  \
# 1388                  NaN                  NaN                  NaN
# 1378  2014-08-24 00:00:00  2014-08-29 00:00:00                  NaN
# 4416  2014-08-05 00:00:00  2014-08-11 00:00:00  2014-08-18 00:00:00
# 3557  2014-08-02 00:00:00  2014-08-08 00:00:00  2014-08-14 00:00:00
# 2105                  NaN                  NaN                  NaN
#
#                Status      Role Type Recruiting Channel  Offer Bonus     City  \
# 1388         Approved  Non-Technical                NaN          NaN    Miami
# 1378          Offered      Technical           LinkedIn      15500.0   Dallas
# 4416           Filled      Technical           Referral      30000.0  Atlanta
# 3557           Filled  Non-Technical           Internal          NaN   Denver
# 2105  Interview start  Non-Technical           LinkedIn          NaN  Seattle
#
#      State
# 1388    FL
# 1378    TX
# 4416    GA
# 3557    CO
# 2105    WA

# %%
df.to_csv("hiring_clean.csv", index=False)
